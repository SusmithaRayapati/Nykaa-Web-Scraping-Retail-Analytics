# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

url = "https://www.nykaa.com/search/result/?q=beauty&root=search&searchType=Manual&sourcepage=home"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)

soup = BeautifulSoup(response.content, "html.parser")

titles = soup.find_all("h2", class_="css-xrzmfa")

print("Number of products:", len(titles))

# Empty list to store product data
products = []

for product in titles[:20]:

    # Product Name
    product_name = product.get_text(strip=True)

    # Product card text
    parent = product.parent
    text = parent.get_text(" ", strip=True)

    # MRP
    mrp_match = re.search(r"Regular price ₹(\d+)", text)

    if mrp_match:
        mrp = mrp_match.group(1)
    else:
        mrp = "N/A"

    # Selling Price
    price_match = re.search(r"Discounted price ₹(\d+)", text)

    if price_match:
        price = price_match.group(1)
    else:
        price = "N/A"

    # Discount
    discount_match = re.search(r"(\d+)% Off", text)

    if discount_match:
        discount = discount_match.group(1) + "%"
    else:
        discount = "N/A"

    # Brand
    brand_match = re.match(r"(\S+)", product_name)

    if brand_match:
        brand = brand_match.group(1)
    else:
        brand = "N/A"

    # Rating
    rating = "N/A"

    current = product

    for i in range(5):

        if current:

            current_text = current.get_text(" ", strip=True)

            rating_match = re.search(r"\b[0-5]\.\d\b", current_text)

            if rating_match:
                rating = rating_match.group(0)
                break

            current = current.parent

    # Reviews
    reviews_match = re.search(r"\(\s*(\d+)\s*\)", text)

    if reviews_match:
        reviews = reviews_match.group(1)
    else:
        reviews = "N/A"

    # Product URL
    link = product.find_parent("a", href=True)

    if link:
        product_url = "https://www.nykaa.com" + link["href"]
    else:
        product_url = "N/A"

    # Category
    category = "Beauty"

    # Store product data
    products.append({
        "Product Name": product_name,
        "Brand": brand,
        "MRP": mrp,
        "Selling Price": price,
        "Discount": discount,
        "Rating": rating,
        "Reviews": reviews,
        "Product URL": product_url,
        "Category": category
    })
# Out:
# Status Code: 200
# Number of products: 20

# %%
df.to_csv("nykaa_beauty_products.csv", index=False)

# %%
# Create DataFrame
df = pd.DataFrame(products)

# Display as table in Jupyter
df

# Save CSV
df.to_csv("nykaa_beauty_products.csv", index=False)

print("CSV file created successfully!")
print("Total products saved:", len(df))
# Out:
# CSV file created successfully!
# Total products saved: 20

# %%
df
# Out:
#                                          Product Name       Brand   MRP  \
# 0         TIRTIR Mask Fit Red Mini Cushion Foundation      TIRTIR  1300
# 1   Swiss Beauty Bold Matt Lip Liner Pencil, Long-...       Swiss    69
# 2   Insight Cosmetics Concealer, Buildabe Coverage...     Insight   135
# 3   Feel Good Club Classic Makeup Blender Beauty S...        Feel   105
# 4   Biolage Smoothproof 6-in-1 Hair Serum for Friz...     Biolage   385
# 5   Beauty of Joseon Relief Sun Aqua-Fresh Add SPF...      Beauty   N/A
# 6   Dot & Key 10% Vitamin C + E Face Serum With 5%...         Dot   499
# 7   Insight Cosmetics 24 Hrs Non Transfer Matte Li...     Insight   310
# 8   Oziva Advanced Hair Growth ActivesReduces Thin...       Oziva  2099
# 9   Dot & Key Cica Calming Mattifying Sunscreen In...         Dot   445
# 10                The Face Shop Real Nature Face Mask         The   N/A
# 11  Nykaa Green Tea + Aloe Vera Sheet Mask For Hyd...       Nykaa   100
# 12  Beauty of Joseon Relief Sunscreen Rice + Probi...      Beauty   N/A
# 13  Dot & Key 72HR Hydrating Gel Moisturizer + Pro...         Dot   495
# 14                           Kay Beauty Matte Compact         Kay   849
# 15           Swiss Beauty Baked Blusher & Highlighter       Swiss   399
# 16          Rare Beauty Soft Pinch Matte Liquid Blush        Rare   N/A
# 17  ETUDE Dear Darling Water Gel Lip and Cheek Tin...       ETUDE   450
# 18  Aqualogica Glow+ Dewy Sunscreen Gel SPF 50+ PA...  Aqualogica   599
# 19  Swiss Beauty Glow Up Makeup Fixer With Vitamin...       Swiss   396
#
#    Selling Price Discount Rating  Reviews  \
# 0           1105      15%    N/A     2408
# 1             66       5%    N/A   313242
# 2            131       3%    N/A    38535
# 3             60      43%    N/A     2355
# 4            308      20%    N/A    42542
# 5            N/A      N/A    N/A     5431
# 6            429      14%    N/A    63254
# 7            295       5%    N/A   545160
# 8           1849      12%    N/A      280
# 9            387      13%    N/A    33451
# 10           N/A      N/A    N/A   181063
# 11            80      20%    N/A  7593355
# 12           N/A      N/A    N/A    20908
# 13           426      14%    N/A    43737
# 14           679      20%    N/A   171931
# 15           299      25%    N/A    49547
# 16           N/A      N/A    N/A      390
# 17           360      20%    N/A    26615
# 18           515      14%    N/A   200409
# 19           356      10%    N/A     5458
#
#                                           Product URL Category
# 0   https://www.nykaa.com/tirtir-mask-fit-red-mini...   Beauty
# 1   https://www.nykaa.com/swiss-beauty-bold-matt-l...   Beauty
# 2   https://www.nykaa.com/insight-cosmetics-concea...   Beauty
# 3   https://www.nykaa.com/feel-good-club-classic-m...   Beauty
# 4   https://www.nykaa.com/matrix-biolage-smooth-pr...   Beauty
# 5   https://www.nykaa.com/beauty-of-joseon-relief-...   Beauty
# 6   https://www.nykaa.com/dot-key-10percent-vitami...   Beauty
# 7   https://www.nykaa.com/insight-cosmetics-24-hrs...   Beauty
# 8   https://www.nykaa.com/oziva-advanced-hair-grow...   Beauty
# 9   https://www.nykaa.com/dot-key-cica-calming-nia...   Beauty
# 10  https://www.nykaa.com/the-face-shop-real-natur...   Beauty
# 11  https://www.nykaa.com/nykaa-skin-secrets-sheet...   Beauty
# 12  https://www.nykaa.com/beauty-of-joseon-relief-...   Beauty
# 13  https://www.nykaa.com/dot-key-glow-72-hr-hydra...   Beauty
# 14  https://www.nykaa.com/kay-beauty-matte-compact...   Beauty
# 15  https://www.nykaa.com/swiss-beauty-baked-blush...   Beauty
# 16  https://www.nykaa.com/rare-beauty-soft-pinch-m...   Beauty
# 17  https://www.nykaa.com/etude-house-dear-daring-...   Beauty
# 18  https://www.nykaa.com/aqualogica-glow-dewy-sun...   Beauty
# 19  https://www.nykaa.com/swiss-beauty-glow-up-mak...   Beauty
